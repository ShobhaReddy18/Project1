# %%
import pandas as pd
#HERE PANDAS HAVE BEEN IMPORTED TO THE WORKSPACE AS 'pd'

# %%
a=pd.read_csv(r"C:\Users\SHOBHA REDDY\Downloads\youtoxic_english_1000.csv")
#reading the csv file which is downloaded from kaggle and assigning it to the variable 'a'

# %%
a
#displaying all the data in form of data frame
# Out:
#      Commentno             CommentId      VideoId  \
# 0            1  Ugg2KwwX0V8-aXgCoAEC  04kJtp6pVXI
# 1            2  Ugg2s5AzSPioEXgCoAEC  04kJtp6pVXI
# 2            3  Ugg3dWTOxryFfHgCoAEC  04kJtp6pVXI
# 3            4  Ugg7Gd006w1MPngCoAEC  04kJtp6pVXI
# 4            5  Ugg8FfTbbNF8IngCoAEC  04kJtp6pVXI
# ..         ...                   ...          ...
# 995        996  Ugi5ADt10EdDz3gCoAEC  XRuCW80L9mA
# 996        997  Ugifh2DMhBbDkHgCoAEC  XRuCW80L9mA
# 997        998  Ugj_plbGBjjzYXgCoAEC  XRuCW80L9mA
# 998        999  Ugj0bah1De8xy3gCoAEC  XRuCW80L9mA
# 999       1000  UgjBJKQSoQMQ6ngCoAEC  XRuCW80L9mA
#
#                                                   Text  IsToxic  IsAbusive  \
# 0    If only people would just take a step back and...    False      False
# 1    Law enforcement is not trained to shoot to app...     True       True
# 2    \nDont you reckon them 'black lives matter' ba...     True       True
# ...

# %%
a.head(300)
#The head() method in pandas returns the first n rows of a DataFrame or Series, with n defaulting to 5 if not specified
# Out:
#      Commentno             CommentId      VideoId  \
# 0            1  Ugg2KwwX0V8-aXgCoAEC  04kJtp6pVXI
# 1            2  Ugg2s5AzSPioEXgCoAEC  04kJtp6pVXI
# 2            3  Ugg3dWTOxryFfHgCoAEC  04kJtp6pVXI
# 3            4  Ugg7Gd006w1MPngCoAEC  04kJtp6pVXI
# 4            5  Ugg8FfTbbNF8IngCoAEC  04kJtp6pVXI
# ..         ...                   ...          ...
# 295        296  Ugg-mmBHT4T8ongCoAEC  9pr1oE34bIM
# 296        297  UggmnZVP_3mtZngCoAEC  9pr1oE34bIM
# 297        298  UggmYvutq7TQT3gCoAEC  9pr1oE34bIM
# 298        299  UggN23XYVd645HgCoAEC  9pr1oE34bIM
# 299        300  Uggn2MEU8ktaUngCoAEC  9pr1oE34bIM
#
#                                                   Text  IsToxic  IsAbusive  \
# 0    If only people would just take a step back and...    False      False
# 1    Law enforcement is not trained to shoot to app...     True       True
# 2    \nDont you reckon them 'black lives matter' ba...     True       True
# ...

# %%
a.dtypes
#The `.dtypes` attribute in pandas returns a Series with the data type of each column in a DataFrame.
# Out:
# Commentno           int64
# CommentId          object
# VideoId            object
# Text               object
# IsToxic              bool
# IsAbusive            bool
# IsThreat             bool
# IsProvocative        bool
# IsObscene            bool
# IsHatespeech         bool
# IsRacist             bool
# IsNationalist        bool
# IsSexist             bool
# IsHomophobic         bool
# IsReligiousHate      bool
# IsRadicalism         bool
# dtype: object

# %%
a.tail()

#this gives last five records by default

#Also able to generate required number data from last
# Out:
#      Commentno             CommentId      VideoId  \
# 995        996  Ugi5ADt10EdDz3gCoAEC  XRuCW80L9mA
# 996        997  Ugifh2DMhBbDkHgCoAEC  XRuCW80L9mA
# 997        998  Ugj_plbGBjjzYXgCoAEC  XRuCW80L9mA
# 998        999  Ugj0bah1De8xy3gCoAEC  XRuCW80L9mA
# 999       1000  UgjBJKQSoQMQ6ngCoAEC  XRuCW80L9mA
#
#                                                   Text  IsToxic  IsAbusive  \
# 995  I remember that they sent in the national defe...    False      False
# 996  Stats don`t represent the problem. Race baitin...     True      False
# 997  The quote from the mother... Wow that hit hard...    False      False
# 998                            this video is so racist    False      False
# 999      God, the narrator has such an annoying lisp.     False      False
#
#      IsThreat  IsProvocative  IsObscene  IsHatespeech  IsRacist  \
# 995     False          False      False         False     False
# 996     False          False      False          True      True
# ...

# %%
a.describe()
# Out:
#          Commentno
# count  1000.000000
# mean    500.500000
# std     288.819436
# min       1.000000
# 25%     250.750000
# 50%     500.500000
# 75%     750.250000
# max    1000.000000

# %%
a.isnull().sum()

#Finding out the missing values count in each and every column
# Out:
# Commentno          0
# CommentId          0
# VideoId            0
# Text               0
# IsToxic            0
# IsAbusive          0
# IsThreat           0
# IsProvocative      0
# IsObscene          0
# IsHatespeech       0
# IsRacist           0
# IsNationalist      0
# IsSexist           0
# IsHomophobic       0
# IsReligiousHate    0
# IsRadicalism       0
# dtype: int64

# %%
#* Data Selection *
a['Text']

#select a particular column --->>> df["name_of_column"]
# Out:
# 0      If only people would just take a step back and...
# 1      Law enforcement is not trained to shoot to app...
# 2      \nDont you reckon them 'black lives matter' ba...
# 3      There are a very large number of people who do...
# 4      The Arab dude is absolutely right, he should h...
#                              ...
# 995    I remember that they sent in the national defe...
# 996    Stats don`t represent the problem. Race baitin...
# 997    The quote from the mother... Wow that hit hard...
# 998                              this video is so racist
# 999        God, the narrator has such an annoying lisp.
# Name: Text, Length: 1000, dtype: object

# %%
a[['VideoId','Text']]

#Select multiple columns --->>> df[["column_1","column_2"]]
# Out:
#          VideoId                                               Text
# 0    04kJtp6pVXI  If only people would just take a step back and...
# 1    04kJtp6pVXI  Law enforcement is not trained to shoot to app...
# 2    04kJtp6pVXI  \nDont you reckon them 'black lives matter' ba...
# 3    04kJtp6pVXI  There are a very large number of people who do...
# 4    04kJtp6pVXI  The Arab dude is absolutely right, he should h...
# ..           ...                                                ...
# 995  XRuCW80L9mA  I remember that they sent in the national defe...
# 996  XRuCW80L9mA  Stats don`t represent the problem. Race baitin...
# 997  XRuCW80L9mA  The quote from the mother... Wow that hit hard...
# 998  XRuCW80L9mA                            this video is so racist
# 999  XRuCW80L9mA      God, the narrator has such an annoying lisp.
#
# [1000 rows x 2 columns]

# %%
b = a[['CommentId','VideoId','Text']]

# %%
b
# Out:
#                 CommentId      VideoId  \
# 0    Ugg2KwwX0V8-aXgCoAEC  04kJtp6pVXI
# 1    Ugg2s5AzSPioEXgCoAEC  04kJtp6pVXI
# 2    Ugg3dWTOxryFfHgCoAEC  04kJtp6pVXI
# 3    Ugg7Gd006w1MPngCoAEC  04kJtp6pVXI
# 4    Ugg8FfTbbNF8IngCoAEC  04kJtp6pVXI
# ..                    ...          ...
# 995  Ugi5ADt10EdDz3gCoAEC  XRuCW80L9mA
# 996  Ugifh2DMhBbDkHgCoAEC  XRuCW80L9mA
# 997  Ugj_plbGBjjzYXgCoAEC  XRuCW80L9mA
# 998  Ugj0bah1De8xy3gCoAEC  XRuCW80L9mA
# 999  UgjBJKQSoQMQ6ngCoAEC  XRuCW80L9mA
#
#                                                   Text
# 0    If only people would just take a step back and...
# 1    Law enforcement is not trained to shoot to app...
# 2    \nDont you reckon them 'black lives matter' ba...
# 3    There are a very large number of people who do...
# 4    The Arab dude is absolutely right, he should h...
# ..                                                 ...
# 995  I remember that they sent in the national defe...
# ...

# %%
type(b)
# Out:
# pandas.core.frame.DataFrame

# %%
a['Text'][1:100:3]

#Selecting rows with the help of indexing --->>> df.iloc[start_index : End_index : Jump]
# Out:
# 1     Law enforcement is not trained to shoot to app...
# 4     The Arab dude is absolutely right, he should h...
# 7     I would LOVE to see this pussy go to Staten Is...
# 10    the guy on the right is so on point. don't jud...
# 13    We all know with the chimpers there is no comp...
# 16    I would'nt waist my time trying to reason with...
# 19    You actually CAN shout "fire" in a crowded the...
# 22                          1 word: Provocateur........
# 25    He looks ready to cut heads off he must be a i...
# 28    This man is a zionist jew look at ypu can see ...
# 31                                      I LIKE TURTLES!
# 34    Hers my statement, I think ali sheep butt fuck...
# 37        A completely idiot having his minutrs of fame
# 40    Alright. This entire case is crap. All of thes...
# 43    Smirconnish is the most even-handed guy in the...
# 46    Let's reverse the rolls! Black racist cops in ...
# 49    Can someone shoot this black idiot too? That w...
# ...

# %%
a[['VideoId','Text']][1:50:4]  #15
# Out:
#         VideoId                                               Text
# 1   04kJtp6pVXI  Law enforcement is not trained to shoot to app...
# 5   04kJtp6pVXI  here people his facebook is https://www.facebo...
# 9   04kJtp6pVXI   mike browns father was made to say that boooshit
# 13  04kJtp6pVXI  We all know with the chimpers there is no comp...
# 17  04kJtp6pVXI                         I wish mr masri was dead,,
# 21  04kJtp6pVXI        LEGALIZE MARIJUANA! Then problems will stop
# 25  04kJtp6pVXI  He looks ready to cut heads off he must be a i...
# 29  04kJtp6pVXI  "There is blood on the street but you are worr...
# 33  04kJtp6pVXI      CNN mother fuckers....fuck you peace of shit!
# 37  04kJtp6pVXI      A completely idiot having his minutrs of fame
# 41  04kJtp6pVXI  This guy doesn't know what happened he didn't ...
# 45  04kJtp6pVXI  He had to take a break because Bassem was maki...
# 49  04kJtp6pVXI  Can someone shoot this black idiot too? That w...

# %%
#16 
a.columns

#view of all the columns present in the dataset
# Out:
# Index(['Commentno', 'CommentId', 'VideoId', 'Text', 'IsToxic', 'IsAbusive',
#        'IsThreat', 'IsProvocative', 'IsObscene', 'IsHatespeech', 'IsRacist',
#        'IsNationalist', 'IsSexist', 'IsHomophobic', 'IsReligiousHate',
#        'IsRadicalism'],
#       dtype='object')

# %%
#17
a[a.dtypes[a.dtypes == 'object'].index]
    
#getting out only object datatypes as a new data frame
# Out:
#                 CommentId      VideoId  \
# 0    Ugg2KwwX0V8-aXgCoAEC  04kJtp6pVXI
# 1    Ugg2s5AzSPioEXgCoAEC  04kJtp6pVXI
# 2    Ugg3dWTOxryFfHgCoAEC  04kJtp6pVXI
# 3    Ugg7Gd006w1MPngCoAEC  04kJtp6pVXI
# 4    Ugg8FfTbbNF8IngCoAEC  04kJtp6pVXI
# ..                    ...          ...
# 995  Ugi5ADt10EdDz3gCoAEC  XRuCW80L9mA
# 996  Ugifh2DMhBbDkHgCoAEC  XRuCW80L9mA
# 997  Ugj_plbGBjjzYXgCoAEC  XRuCW80L9mA
# 998  Ugj0bah1De8xy3gCoAEC  XRuCW80L9mA
# 999  UgjBJKQSoQMQ6ngCoAEC  XRuCW80L9mA
#
#                                                   Text
# 0    If only people would just take a step back and...
# 1    Law enforcement is not trained to shoot to app...
# 2    \nDont you reckon them 'black lives matter' ba...
# 3    There are a very large number of people who do...
# 4    The Arab dude is absolutely right, he should h...
# ..                                                 ...
# 995  I remember that they sent in the national defe...
# ...

# %%
#18 describing the statistical data for categorical items
a[a.dtypes[a.dtypes == 'object'].index].describe()
# Out:
#                    CommentId      VideoId           Text
# count                   1000         1000           1000
# unique                  1000           13            997
# top     Ugg2KwwX0V8-aXgCoAEC  9pr1oE34bIM  run them over
# freq                       1          274              3

# %%
#19 creating of new data frame "Youtube_Comments".

#Some more operations on 'Youtube_Comments'
a = pd.read_csv(r"C:\Users\SHOBHA REDDY\Downloads\youtoxic_english_1000.csv")

# %%
#20
Youtube_Comments= a.head(156)

#Accessing of all the 156 top data

# %%
#21
Youtube_Comments
# Out:
#      Commentno             CommentId      VideoId  \
# 0            1  Ugg2KwwX0V8-aXgCoAEC  04kJtp6pVXI
# 1            2  Ugg2s5AzSPioEXgCoAEC  04kJtp6pVXI
# 2            3  Ugg3dWTOxryFfHgCoAEC  04kJtp6pVXI
# 3            4  Ugg7Gd006w1MPngCoAEC  04kJtp6pVXI
# 4            5  Ugg8FfTbbNF8IngCoAEC  04kJtp6pVXI
# ..         ...                   ...          ...
# 151        152  UgjqUwip_APfmXgCoAEC  04kJtp6pVXI
# 152        153  UgjrGaGIqNBEk3gCoAEC  04kJtp6pVXI
# 153        154  UgjsJRASPa3OWHgCoAEC  04kJtp6pVXI
# 154        155  UgjUmLh6NzcUIHgCoAEC  04kJtp6pVXI
# 155        156  UgjuofaJSKK4uXgCoAEC  04kJtp6pVXI
#
#                                                   Text  IsToxic  IsAbusive  \
# 0    If only people would just take a step back and...    False      False
# 1    Law enforcement is not trained to shoot to app...     True       True
# 2    \nDont you reckon them 'black lives matter' ba...     True       True
# ...

# %%
#22
Youtube_Comments.head()
# Out:
#    Commentno             CommentId      VideoId  \
# 0          1  Ugg2KwwX0V8-aXgCoAEC  04kJtp6pVXI
# 1          2  Ugg2s5AzSPioEXgCoAEC  04kJtp6pVXI
# 2          3  Ugg3dWTOxryFfHgCoAEC  04kJtp6pVXI
# 3          4  Ugg7Gd006w1MPngCoAEC  04kJtp6pVXI
# 4          5  Ugg8FfTbbNF8IngCoAEC  04kJtp6pVXI
#
#                                                 Text  IsToxic  IsAbusive  \
# 0  If only people would just take a step back and...    False      False
# 1  Law enforcement is not trained to shoot to app...     True       True
# 2  \nDont you reckon them 'black lives matter' ba...     True       True
# 3  There are a very large number of people who do...    False      False
# 4  The Arab dude is absolutely right, he should h...    False      False
#
#    IsThreat  IsProvocative  IsObscene  IsHatespeech  IsRacist  IsNationalist  \
# 0     False          False      False         False     False          False
# 1     False          False      False         False     False          False
# ...

# %%
#23
Youtube_Comments.tail() #accessing last 5 elements from bottom
# Out:
#      Commentno             CommentId      VideoId  \
# 151        152  UgjqUwip_APfmXgCoAEC  04kJtp6pVXI
# 152        153  UgjrGaGIqNBEk3gCoAEC  04kJtp6pVXI
# 153        154  UgjsJRASPa3OWHgCoAEC  04kJtp6pVXI
# 154        155  UgjUmLh6NzcUIHgCoAEC  04kJtp6pVXI
# 155        156  UgjuofaJSKK4uXgCoAEC  04kJtp6pVXI
#
#                                                   Text  IsToxic  IsAbusive  \
# 151  people get shot everyday, how come this is the...    False      False
# 152  Why is it that in the history of mankind where...     True      False
# 153                          What a fucking douche bag     True       True
# 154  CNN needs to hire that man. He is a real Ameri...     True       True
# 155  One feral hoodlum put down, the rest of us no ...     True      False
#
#      IsThreat  IsProvocative  IsObscene  IsHatespeech  IsRacist  \
# 151     False          False      False         False     False
# 152     False          False      False          True      True
# ...

# %%
#24
Youtube_Comments.columns
# Out:
# Index(['Commentno', 'CommentId', 'VideoId', 'Text', 'IsToxic', 'IsAbusive',
#        'IsThreat', 'IsProvocative', 'IsObscene', 'IsHatespeech', 'IsRacist',
#        'IsNationalist', 'IsSexist', 'IsHomophobic', 'IsReligiousHate',
#        'IsRadicalism'],
#       dtype='object')

# %%
#25
Youtube_Comments.dtypes
# Out:
# Commentno           int64
# CommentId          object
# VideoId            object
# Text               object
# IsToxic              bool
# IsAbusive            bool
# IsThreat             bool
# IsProvocative        bool
# IsObscene            bool
# IsHatespeech         bool
# IsRacist             bool
# IsNationalist        bool
# IsSexist             bool
# IsHomophobic         bool
# IsReligiousHate      bool
# IsRadicalism         bool
# dtype: object

# %%
#26 pd.Categorical represents data based on the categories present in the data frame
pd.Categorical(Youtube_Comments)
# Out:
# ['Commentno', 'CommentId', 'VideoId', 'Text', 'IsToxic', ..., 'IsNationalist', 'IsSexist', 'IsHomophobic', 'IsReligiousHate', 'IsRadicalism']
# Length: 16
# Categories (16, object): ['CommentId', 'Commentno', 'IsAbusive', 'IsHatespeech', ..., 'IsThreat', 'IsToxic', 'Text', 'VideoId']

# %%
#27
pd.Categorical(Youtube_Comments["VideoId"])
# Out:
# ['04kJtp6pVXI', '04kJtp6pVXI', '04kJtp6pVXI', '04kJtp6pVXI', '04kJtp6pVXI', ..., '04kJtp6pVXI', '04kJtp6pVXI', '04kJtp6pVXI', '04kJtp6pVXI', '04kJtp6pVXI']
# Length: 156
# Categories (1, object): ['04kJtp6pVXI']

# %%
#28
pd.Categorical(Youtube_Comments["Text"])
# Out:
# ['If only people would just take a step back an..., 'Law enforcement is not trained to shoot to ap..., '\nDont you reckon them 'black lives matter' b..., 'There are a very large number of people who d..., 'The Arab dude is absolutely right, he should ..., ..., 'people get shot everyday, how come this is th..., 'Why is it that in the history of mankind wher..., 'What a fucking douche bag', 'CNN needs to hire that man. He is a real Amer..., 'One feral hoodlum put down, the rest of us no...]
# Length: 156
# Categories (156, object): ['\nDont you reckon them 'black lives matter' b..., '"I can believe whatever I wanna believe, I do..., '"I don't want my sons death to be in vain." "..., '"There is blood on the street but you are wor..., ..., 'this fucking fuck can't even defend himself p..., 'this guy here he needs to grow up.', ' Michael Smerconish + Hack. ', ' This is a CIA agent provocateur operative to...]

# %%
#29
type(Youtube_Comments.dtypes)
# Out:
# pandas.core.series.Series

# %%
#30 series
dy = Youtube_Comments.dtypes

#STORING OF DTYPES OF DATAFRAME INSIDE A VARIABLE

# %%
#31
dy
# Out:
# Commentno           int64
# CommentId          object
# VideoId            object
# Text               object
# IsToxic              bool
# IsAbusive            bool
# IsThreat             bool
# IsProvocative        bool
# IsObscene            bool
# IsHatespeech         bool
# IsRacist             bool
# IsNationalist        bool
# IsSexist             bool
# IsHomophobic         bool
# IsReligiousHate      bool
# IsRadicalism         bool
# dtype: object

# %%
#32
dy['Commentno']

#Accessing of data with the name of index
# Out:
# dtype('int64')

# %%
#33
dy[0]

#Also possible to access  data with the help of index
# Out:
# C:\Users\SHOBHA REDDY\AppData\Local\Temp\ipykernel_21304\894103416.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dy[0]
# dtype('int64')

# %%
#34
l = [1,2,3,54,6,"huu","vukja","ineuroi"]

# %%
#35
l[3]
# Out:
# 54

# %%
#36
l[5]
# Out:
# 'huu'

# %%
#37
# In the list data has been extracted on indexes

# In series are also indexes are available but it has data.

# In series it will be possible to store data in indexes.
dy[0:8]

#Performing of slicing operations on series
# Out:
# Commentno         int64
# CommentId        object
# VideoId          object
# Text             object
# IsToxic            bool
# IsAbusive          bool
# IsThreat           bool
# IsProvocative      bool
# dtype: object

# %%
#38
dy[0:100:2] 
#Also considering the slicing operation with a jump of'2'. Hence that is also possible in pandas.
# Out:
# Commentno           int64
# VideoId            object
# IsToxic              bool
# IsThreat             bool
# IsObscene            bool
# IsRacist             bool
# IsSexist             bool
# IsReligiousHate      bool
# dtype: object

# %%
#39
#Advantage in series is we can able to get data by name of index or just mentioning the index. 
l["huu"] # it is not possible in list to get data by considering names of index.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[74], line 3
#       1 #39
#       2 #Advantage in series is we can able to get data by name of index or just mentioning the index.
# ----> 3 l["huu"]
#
# TypeError: list indices must be integers or slices, not str

# %%
#40 Reversing the columns
dy[::-1]
# Out:
# IsRadicalism         bool
# IsReligiousHate      bool
# IsHomophobic         bool
# IsSexist             bool
# IsNationalist        bool
# IsRacist             bool
# IsHatespeech         bool
# IsObscene            bool
# IsProvocative        bool
# IsThreat             bool
# IsAbusive            bool
# IsToxic              bool
# Text               object
# VideoId            object
# CommentId          object
# Commentno           int64
# dtype: object

# %%
#41
Youtube_Comments
# Out:
#      Commentno             CommentId      VideoId  \
# 0            1  Ugg2KwwX0V8-aXgCoAEC  04kJtp6pVXI
# 1            2  Ugg2s5AzSPioEXgCoAEC  04kJtp6pVXI
# 2            3  Ugg3dWTOxryFfHgCoAEC  04kJtp6pVXI
# 3            4  Ugg7Gd006w1MPngCoAEC  04kJtp6pVXI
# 4            5  Ugg8FfTbbNF8IngCoAEC  04kJtp6pVXI
# ..         ...                   ...          ...
# 151        152  UgjqUwip_APfmXgCoAEC  04kJtp6pVXI
# 152        153  UgjrGaGIqNBEk3gCoAEC  04kJtp6pVXI
# 153        154  UgjsJRASPa3OWHgCoAEC  04kJtp6pVXI
# 154        155  UgjUmLh6NzcUIHgCoAEC  04kJtp6pVXI
# 155        156  UgjuofaJSKK4uXgCoAEC  04kJtp6pVXI
#
#                                                   Text  IsToxic  IsAbusive  \
# 0    If only people would just take a step back and...    False      False
# 1    Law enforcement is not trained to shoot to app...     True       True
# 2    \nDont you reckon them 'black lives matter' ba...     True       True
# ...

# %%
#42
Youtube_Comments.head()
# Out:
#    Commentno             CommentId      VideoId  \
# 0          1  Ugg2KwwX0V8-aXgCoAEC  04kJtp6pVXI
# 1          2  Ugg2s5AzSPioEXgCoAEC  04kJtp6pVXI
# 2          3  Ugg3dWTOxryFfHgCoAEC  04kJtp6pVXI
# 3          4  Ugg7Gd006w1MPngCoAEC  04kJtp6pVXI
# 4          5  Ugg8FfTbbNF8IngCoAEC  04kJtp6pVXI
#
#                                                 Text  IsToxic  IsAbusive  \
# 0  If only people would just take a step back and...    False      False
# 1  Law enforcement is not trained to shoot to app...     True       True
# 2  \nDont you reckon them 'black lives matter' ba...     True       True
# 3  There are a very large number of people who do...    False      False
# 4  The Arab dude is absolutely right, he should h...    False      False
#
#    IsThreat  IsProvocative  IsObscene  IsHatespeech  IsRacist  IsNationalist  \
# 0     False          False      False         False     False          False
# 1     False          False      False         False     False          False
# ...

# %%
#43
Youtube_Comments['Text'] #Accesing of column data
# Out:
# 0      If only people would just take a step back and...
# 1      Law enforcement is not trained to shoot to app...
# 2      \nDont you reckon them 'black lives matter' ba...
# 3      There are a very large number of people who do...
# 4      The Arab dude is absolutely right, he should h...
#                              ...
# 151    people get shot everyday, how come this is the...
# 152    Why is it that in the history of mankind where...
# 153                            What a fucking douche bag
# 154    CNN needs to hire that man. He is a real Ameri...
# 155    One feral hoodlum put down, the rest of us no ...
# Name: Text, Length: 156, dtype: object

# %%
#44
type(Youtube_Comments['Text'])
# Out:
# pandas.core.series.Series

# %%
#45 enclsoe the column in list of list to get the data been stored in dataframe
Youtube_Comments[['Text']]
# Out:
#                                                   Text
# 0    If only people would just take a step back and...
# 1    Law enforcement is not trained to shoot to app...
# 2    \nDont you reckon them 'black lives matter' ba...
# 3    There are a very large number of people who do...
# 4    The Arab dude is absolutely right, he should h...
# ..                                                 ...
# 151  people get shot everyday, how come this is the...
# 152  Why is it that in the history of mankind where...
# 153                          What a fucking douche bag
# 154  CNN needs to hire that man. He is a real Ameri...
# 155  One feral hoodlum put down, the rest of us no ...
#
# [156 rows x 1 columns]

# %%
#46
type(Youtube_Comments[['Text']])
# Out:
# pandas.core.frame.DataFrame

# %%
#47
#give data set from Text column startinhg from 5 to 100 index
Youtube_Comments[['Text']][5:100]
# Out:
#                                                  Text
# 5   here people his facebook is https://www.facebo...
# 6   Check out this you tube post. "Black man goes ...
# 7   I would LOVE to see this pussy go to Staten Is...
# 8                         I agree with the protestor.
# 9    mike browns father was made to say that boooshit
# ..                                                ...
# 95  It's not about just Brown, it's about daily ki...
# 96             How was this guy hired?\nWhat an idiot
# 97                               This guy is a moron.
# 98  Cnn...so out of touch..close up idiots.. peopl...
# 99  Bassem Masri is a criminal, a thug and a psych...
#
# [95 rows x 1 columns]

# %%
#48
#printing of data in reverse direction 
Youtube_Comments[['Text']][::-1]
# Out:
#                                                   Text
# 155  One feral hoodlum put down, the rest of us no ...
# 154  CNN needs to hire that man. He is a real Ameri...
# 153                          What a fucking douche bag
# 152  Why is it that in the history of mankind where...
# 151  people get shot everyday, how come this is the...
# ..                                                 ...
# 4    The Arab dude is absolutely right, he should h...
# 3    There are a very large number of people who do...
# 2    \nDont you reckon them 'black lives matter' ba...
# 1    Law enforcement is not trained to shoot to app...
# 0    If only people would just take a step back and...
#
# [156 rows x 1 columns]

# %%
#49
#negative indexes not be able to access in series
#not exist in series 
#in list we can able to get -ve index

Youtube_Comments[-1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File G:\Project\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: -1
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[88], line 6
#       1 #49
#       2 #negative indexes not be able to access in series
# ...

# %%
#50
#accesss data at every second index
list(Youtube_Comments['Text'][::2])
# Out:
# ["If only people would just take a step back and not make this case about them, because it wasn't about anyone except the two people in that situation.\xa0 To lump yourself into this mess and take matters into your own hands makes these kinds of protests selfish and without rational thought and investigation.\xa0 The guy in this video is heavily emotional and hyped up and wants to be heard, and when he gets heard he just presses more and more.\xa0 He was never out to have a reasonable discussion.\xa0 Kudos to the Smerconish for keeping level the whole time and letting Masri make himself out to be a fool.\xa0 How dare he and those that tore that city down in protest make this about themselves and to dishonor the entire incident with their own hate.\xa0 By the way, since when did police brutality become an epidemic?\xa0 I wish everyone would just stop pretending like they were there and they knew EXACTLY what was going on, because there's no measurable amount of people that honestly wi
# ...

# %%
#51
Youtube_Comments.dtypes
# Out:
# Commentno           int64
# CommentId          object
# VideoId            object
# Text               object
# IsToxic              bool
# IsAbusive            bool
# IsThreat             bool
# IsProvocative        bool
# IsObscene            bool
# IsHatespeech         bool
# IsRacist             bool
# IsNationalist        bool
# IsSexist             bool
# IsHomophobic         bool
# IsReligiousHate      bool
# IsRadicalism         bool
# dtype: object

# %%
#52
#finding out of ststistical data from data 
Youtube_Comments.describe()
# Out:
#         Commentno
# count  156.000000
# mean    78.500000
# std     45.177428
# min      1.000000
# 25%     39.750000
# 50%     78.500000
# 75%    117.250000
# max    156.000000

# %%
#53
#EXTRACTING THE CATEGORICAL DATA FROM TABLE 
Youtube_Comments.dtypes == 'object'
# Out:
# Commentno          False
# CommentId           True
# VideoId             True
# Text                True
# IsToxic            False
# IsAbusive          False
# IsThreat           False
# IsProvocative      False
# IsObscene          False
# IsHatespeech       False
# IsRacist           False
# IsNationalist      False
# IsSexist           False
# IsHomophobic       False
# IsReligiousHate    False
# IsRadicalism       False
# dtype: bool

# %%
#54
Youtube_Comments.dtypes[Youtube_Comments.dtypes == 'object']
# Out:
# CommentId    object
# VideoId      object
# Text         object
# dtype: object

# %%
#55
df2=Youtube_Comments.dtypes[Youtube_Comments.dtypes == 'object']

# %%
#56
df2.index
# Out:
# Index(['CommentId', 'VideoId', 'Text'], dtype='object')

# %%
#57
Youtube_Comments[Youtube_Comments.dtypes[Youtube_Comments.dtypes == 'object'].index]
# Out:
#                 CommentId      VideoId  \
# 0    Ugg2KwwX0V8-aXgCoAEC  04kJtp6pVXI
# 1    Ugg2s5AzSPioEXgCoAEC  04kJtp6pVXI
# 2    Ugg3dWTOxryFfHgCoAEC  04kJtp6pVXI
# 3    Ugg7Gd006w1MPngCoAEC  04kJtp6pVXI
# 4    Ugg8FfTbbNF8IngCoAEC  04kJtp6pVXI
# ..                    ...          ...
# 151  UgjqUwip_APfmXgCoAEC  04kJtp6pVXI
# 152  UgjrGaGIqNBEk3gCoAEC  04kJtp6pVXI
# 153  UgjsJRASPa3OWHgCoAEC  04kJtp6pVXI
# 154  UgjUmLh6NzcUIHgCoAEC  04kJtp6pVXI
# 155  UgjuofaJSKK4uXgCoAEC  04kJtp6pVXI
#
#                                                   Text
# 0    If only people would just take a step back and...
# 1    Law enforcement is not trained to shoot to app...
# 2    \nDont you reckon them 'black lives matter' ba...
# 3    There are a very large number of people who do...
# 4    The Arab dude is absolutely right, he should h...
# ..                                                 ...
# 151  people get shot everyday, how come this is the...
# ...

# %%
#58
YCC = Youtube_Comments[Youtube_Comments.dtypes[Youtube_Comments.dtypes == 'object'].index]

# %%
#59
YCC.describe()
# Out:
#                    CommentId      VideoId  \
# count                    156          156
# unique                   156            1
# top     Ugg2KwwX0V8-aXgCoAEC  04kJtp6pVXI
# freq                       1          156
#
#                                                      Text
# count                                                 156
# unique                                                156
# top     If only people would just take a step back and...
# freq                                                    1

# %%
#60
Youtube_Comments.columns
# Out:
# Index(['Commentno', 'CommentId', 'VideoId', 'Text', 'IsToxic', 'IsAbusive',
#        'IsThreat', 'IsProvocative', 'IsObscene', 'IsHatespeech', 'IsRacist',
#        'IsNationalist', 'IsSexist', 'IsHomophobic', 'IsReligiousHate',
#        'IsRadicalism'],
#       dtype='object')

# %%
Youtube_Comments
# Out:
#      Commentno             CommentId      VideoId  \
# 0            1  Ugg2KwwX0V8-aXgCoAEC  04kJtp6pVXI
# 1            2  Ugg2s5AzSPioEXgCoAEC  04kJtp6pVXI
# 2            3  Ugg3dWTOxryFfHgCoAEC  04kJtp6pVXI
# 3            4  Ugg7Gd006w1MPngCoAEC  04kJtp6pVXI
# 4            5  Ugg8FfTbbNF8IngCoAEC  04kJtp6pVXI
# ..         ...                   ...          ...
# 151        152  UgjqUwip_APfmXgCoAEC  04kJtp6pVXI
# 152        153  UgjrGaGIqNBEk3gCoAEC  04kJtp6pVXI
# 153        154  UgjsJRASPa3OWHgCoAEC  04kJtp6pVXI
# 154        155  UgjUmLh6NzcUIHgCoAEC  04kJtp6pVXI
# 155        156  UgjuofaJSKK4uXgCoAEC  04kJtp6pVXI
#
#                                                   Text  IsToxic  IsAbusive  \
# 0    If only people would just take a step back and...    False      False
# 1    Law enforcement is not trained to shoot to app...     True       True
# 2    \nDont you reckon them 'black lives matter' ba...     True       True
# ...
